# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthikabheemaraj/codingboardpy/blob/main/python_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables and datatypes

# %%
name = "keerthika"
age = 20
cgpa = 8.5
is_student =  True
print("name:",name)
print("age:",age)
print("cgpa:",cgpa)
print("student:",is_student)
# Out:
# name: keerthika
# age: 20
# cgpa: 8.5
# student: True

# %% [markdown]
# operators and experssions

# %%
a = 10
b = 20
c = 30
print("Addition:",a+b)
print("Subtraction:",a-b)
print("Multiplication:",a*b)
print("Division:",a/b)
print("Modulus:",a%b)
print("Exponent:",a**b)
print("Floor Division:",a//b)
result = (a+b)*c
print("result:",result)
# Out:
# Addition: 30
# Subtraction: -10
# Multiplication: 200
# Division: 0.5
# Modulus: 10
# Exponent: 100000000000000000000
# Floor Division: 0
# result: 900

# %% [markdown]
# user input program

# %%
name = input("enter student name:")
print("student name:",name)
age = int(input("enter student age:"))
print("student age:",age)
cgpa = float(input("enter student cgpa:"))
print("student cgpa:",cgpa)
is_student = bool(input("enter student status:"))
print("student status:",is_student)
english = int(input("enter student english marks:"))
maths = int(input("enter student maths marks:"))
science = int(input("enter student science marks:"))
total_marks = english+maths+science
print("total marks:",total_marks)
# Out:
# enter student name:sara
# student name: sara
# enter student age:20
# student age: 20
# enter student cgpa:8.5
# student cgpa: 8.5
# enter student status:student
# student status: True
# enter student english marks:90
# enter student maths marks:85
# enter student science marks:88
# total marks: 263

# %% [markdown]
# student marks calculator

# %%
name = input("enter student name:")
english = int(input("enter student english marks:"))
maths = int(input("enter student maths marks:"))
science = int(input("enter student science marks:"))
social = int(input("enter student social marks:"))
language = int(input("enter student language marks:"))
total_marks = english+maths+science+social+language
print("total marks:",total_marks)
percentage = (total_marks/500)*100
print("percentage:",percentage)
# Out:
# enter student name:joel
# enter student english marks:96
# enter student maths marks:85
# enter student science marks:83
# enter student social marks:92
# enter student language marks:90
# total marks: 446
# percentage: 89.2

# %% [markdown]
# DAY 2
# conditional statements and loops

# %%
marks = int(input("enter marks:"))
if marks >= 90:
  print("grade A")
elif marks >= 80:
  print("grade B")
elif marks >= 70:
  print("grade C")
elif marks >= 60:
  print("grade D")
else:
  print("grade E")
# Out:
# enter marks:60
# grade D

# %% [markdown]
# loops and iterations

# %%
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
count = 1
while count <= 5:
  print(count)
  count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,6):
  if i == 3:
    break
  print(i)
# Out:
# 1
# 2

# %%
for i in range(1,6):
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
for i in range(1,4):
  pass
  print(i)
# Out:
# 1
# 2
# 3

# %%
for i in range(5):
  print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello

# %% [markdown]
# number guessing program

# %%
secret = 7
num = int(input("enter the number"))
while num != secret:
  print("wrong guess")
  num = int(input("enter the number"))
print("correct guess")
# Out:
# enter the number6
# wrong guess
# enter the number5
# wrong guess
# enter the number1
# wrong guess
# enter the number7
# correct guess

# %% [markdown]
# attendance calculator

# %%
name = input("Enter student name: ")
total_classes = int(input("Enter total classes: "))
present_classes = int(input("Enter present classes: "))
attendance = (present_classes / total_classes) * 100
print("Attendance Percentage:", attendance)
if attendance >= 75:
    print("Eligible for Exam")
else:
    print("Not Eligible for Exam")
# Out:
# Enter student name: micky
# Enter total classes: 90
# Enter present classes: 70
# Attendance Percentage: 77.77777777777779
# Eligible for Exam
