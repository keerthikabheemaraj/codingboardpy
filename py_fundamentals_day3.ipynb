# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthikabheemaraj/codingboardpy/blob/main/py_fundamentals_day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# function in python

# %%
name = "sam"
print(name)
name1 = input("enter name:")
print("name:",name1)
text = "hello"
print(len(text))
a = 23
print("type of 'a' is:",type(a))
# Out:
# sam
# enter name:sam
# name: sam
# 5
# type of 'a' is: <class 'int'>

# %% [markdown]
# list and dictionaries

# %%
a = ["aa","bb","cc","dd"]
print(a)
print(a[1])
a[2] = "zz"
print(a)
a.append("ee")
print(a)
a.insert(3,"cc")
print(a)
a.remove("zz")
print(a)
a.pop()
print(a)
# Out:
# ['aa', 'bb', 'cc', 'dd']
# bb
# ['aa', 'bb', 'zz', 'dd']
# ['aa', 'bb', 'zz', 'dd', 'ee']
# ['aa', 'bb', 'zz', 'cc', 'dd', 'ee']
# ['aa', 'bb', 'cc', 'dd', 'ee']
# ['aa', 'bb', 'cc', 'dd']

# %% [markdown]
# file handling

# %%
file = open("student.txt", "w")
file.write("Name: alwin")
file.write("\nDepartment: civil")
file.close()
file = open("student.txt", "r")
data = file.read()
print("File Content:")
print(data)
file.close()
file = open("student.txt", "a")
file.write("\nYear: 3rd Year")
file.close()
with open("student.txt", "r") as file:
    print("\nUpdated File:")
    print(file.read())
# Out:
# File Content:
# Name: alwin
# Department: civil
#
# Updated File:
# Name: alwin
# Department: civil
# Year: 3rd Year

# %% [markdown]
# employee record system

# %%
while True:
    print("\n--- Employee Record System ---")
    print("1. Add Employee")
    print("2. View Employees")
    print("3. Exit")
    choice = input("Enter your choice: ")
    if choice == "1":
        emp_id = input("Enter Employee ID: ")
        emp_name = input("Enter Employee Name: ")
        emp_salary = input("Enter Employee Salary: ")
        file = open("employees.txt", "a")
        file.write(emp_id + " ")
        file.write(emp_name + " ")
        file.write(emp_salary + "\n")
        file.close()
        print("Employee Record Added Successfully")
    elif choice == "2":
        file = open("employees.txt", "r")
        data = file.read()
        print("\nEmployee Records:")
        print(data)
        file.close()
    elif choice == "3":
        print("Exiting Program...")
        break
    else:
        print("Invalid Choice")
# Out:
# --- Employee Record System ---
# 1. Add Employee
# 2. View Employees
# 3. Exit
# Enter your choice: 1
# Enter Employee ID: 2001
# Enter Employee Name: joy
# Enter Employee Salary: 25000
# Employee Record Added Successfully
#
# --- Employee Record System ---
# 1. Add Employee
# 2. View Employees
# 3. Exit
# Enter your choice: 2
#
# Employee Records:
# 2001 joy 25000
# 2001id: joyname: 25000
# 2001id: joyname: 25000
# 2001 joy 25000
#
#
# --- Employee Record System ---
# 1. Add Employee
# 2. View Employees
# 3. Exit
# Enter your choice: 3
# Exiting Program...
